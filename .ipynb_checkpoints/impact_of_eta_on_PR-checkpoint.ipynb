# %% [markdown]
# ## Using Prejudice Remover to Test Impact of Eta

# %% [markdown]
# ## How To Use
# All function definitions are present in "functions_file.py".
# <br>
# These functions all come with the appropriate docstrings that give their defintion and usage.
# <br><br>
# To run the functions, please use the following syntax (as with all functions):
#     <br>
#     <b>functions_file.<i>insert_function_here</i></b>
# <br>
# An example use of this code is found below, as well as how to import it locally.
# <br><br>
# Sources and Credits:
# - [Kaggle](https://www.kaggle.com/search?q=bias+in+ml) for looking at example code.
# - [Towards Data Science](https://towardsdatascience.com/understanding-and-reducing-bias-in-machine-learning-6565e23900ac) for learning and PR examples.
# - [This website](https://aif360.mybluemix.net/) for visualization and learning purposes.

# %% [markdown]
# Ignoring warnings having to do with imports from the <b>AIF360</b> library.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing the python file with all of the necessary functions.

# %%
import functions_file

# %% [markdown]
# Test usage with an <b>eta</b> value of <b>0</b>.
# <br><br>
# The goal was to try and have the function produce plots for a range of eta values, however this couldn't be done due to computational costs and my own memory limitationss. Perhaps that can be solved next semester.
# <br><br>
# Below I will compare the fairness metrics using the following values of eta:
# - 0
# - 250

# %%
functions_file.fetch_input(0)
# Out:
# Accuracy of the model :
# 0.6681104493773687
# F1 score of the model :
# 0.6433973240255962
#            statistical_parity_difference  equal_opportunity_difference  \
# objective                       0.000000                      0.000000
# sex                             0.294743                      0.225753
# race                            0.275628                      0.200602
#
#            average_abs_odds_difference  disparate_impact
# objective                     0.000000          1.000000
# sex                           0.279940          2.345565
# race                          0.255921          1.957770

# %%
functions_file.fetch_input(250)
# Out:
# Accuracy of the model :
# 0.665674066053059
# F1 score of the model :
# 0.6129739893450329
#            statistical_parity_difference  equal_opportunity_difference  \
# objective                       0.000000                      0.000000
# sex                             0.301911                      0.197125
# race                            0.214372                      0.127973
#
#            average_abs_odds_difference  disparate_impact
# objective                     0.000000          1.000000
# sex                           0.274371          2.748807
# race                          0.180764          1.742233

# %% [markdown]
# ### As you can see by comparing the two output tables:
# - With ETA=0, statistical_parity_difference is worse than with ETA=250 for both sex and race.
# - With ETA=0, equal_opportunity_difference is better than with ETA=250 for sex and race (relatively).
# - With ETA=0, average_abs_odds_difference is better than with ETA=250 for sex, but not for race.
# - With ETA=0, disparate_impact is worse than with ETA=250 for both sex and race.
